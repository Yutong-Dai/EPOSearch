# %%
from problems.toy_biobjective_yd import *

# %%
theta = np.linspace(-3, 3, 100)
l1 = [f1(np.array([x])) for x in theta]
l2 = [f2(np.array([x])) for x in theta]
fig, axes = plt.subplots(1,2,figsize=(10,4))
fig.subplots_adjust(left=0.025, bottom=.12, right=.975, top=.975)
axes[0].spines['left'].set_position('zero')
axes[0].spines['right'].set_color('none')    # turn off the right spine/ticks
axes[0].spines['top'].set_color('none')      # turn off the top spine/ticks
axes[0].xaxis.tick_bottom()

axes[0].plot(theta, l1, label=r'$l_1(\theta)$', lw=2)
axes[0].plot(theta, l2, label=r'$l_2(\theta)$', lw=2)
axes[0].legend()
axes[0].set_xlabel(r'$\theta$')
axes[0].xaxis.set_label_coords(0.99, -0.03)
# pf, fs_left, fs_right = create_pf(side_nonpf=False)
pf = create_pf(side_nonpf=False)
axes[1].plot(pf[:,0], pf[:,1], 'k-')
# plt.plot(fs_left[:,0], fs_left[:,1], 'r.')
# plt.plot(fs_right[:,0], fs_right[:,1], 'b.')
axes[1].set_xlabel(r'$l_1(\theta)$')
axes[1].set_ylabel(r'$l_2(\theta)$')
axes[1].set_aspect('equal')

# %%
theta = np.linspace(-3, 3, 100)
l1 = [f1(np.array([x])) for x in theta]
l2 = [f2(np.array([x])) for x in theta]
fig, axes = plt.subplots(1,2,figsize=(10,5))
fig.subplots_adjust(left=0.025, bottom=.12, right=.975, top=.975)
axes[0].spines['left'].set_position('zero')
axes[0].spines['right'].set_color('none')    # turn off the right spine/ticks
axes[0].spines['top'].set_color('none')      # turn off the top spine/ticks
axes[0].xaxis.tick_bottom()

axes[0].plot(theta, l1, label=r'$l_1(\theta)$', lw=2)
axes[0].plot(theta, l2, label=r'$l_2(\theta)$', lw=2)
axes[0].legend()
axes[0].set_xlabel(r'$\theta$')
axes[0].xaxis.set_label_coords(0.99, -0.03)
axes[1].set_aspect('equal')

theta = np.linspace(-1, 1, 100)
l1 = [f1(np.array([x])) for x in theta]
l2 = [f2(np.array([x])) for x in theta]

axes[1].plot(l1, l2, 'k-')
axes[1].set_xlabel(r'$l_1(\theta)$')
axes[1].set_ylabel(r'$l_2(\theta)$')
axes[1].set_aspect('equal')
plt.savefig('./figures/moo_synthetic_both.pdf')
