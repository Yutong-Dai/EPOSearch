# %%
import pickle
# load data from pkl
with open('data/multi_mnist.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
X_train, y_train, X_test, y_test = data

# %%
X_train.shape, y_train.shape
# Out:
# ((120000, 36, 36), (120000, 2))

# %%
# display the first training example
import matplotlib.pyplot as plt
print(y_train[2])
plt.imshow(X_train[2].reshape(36, 36), cmap='gray')
# Out:
# [4 8]
